# %% [markdown]
# <a href="https://colab.research.google.com/github/iiithat/AIMLtraining_AT/blob/main/Ex_1_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

x=np.random.random(100) # 100 numbers between 0-1 normally distributed
y=np.random.normal(size=100) #

#plt.hist(x, bins=20) # histogram
#plt.hist(y, bins=20, color='blue') # histogram normal
#sns.histplot(x,bins=20,kde=True) # Kernel Distribution estimation

# %%
sns.histplot(y,bins=20,kde=True) # Kernel Distribution estimation
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(y, color='magenta', fill=True)

# %%
sns.kdeplot(x, color='blue', fill=True)
sns.kdeplot(y, color='magenta', fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.kdeplot(x, color='blue', fill=True)
plt.subplot(1,2,2)
sns.kdeplot(y, color='red', fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(2,1,1)
sns.kdeplot(x, color='blue', fill=True)
plt.subplot(2,1,2)
sns.kdeplot(y, color='red', fill=True)
# Out:
# <Axes: ylabel='Density'>
